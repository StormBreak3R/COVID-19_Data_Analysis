# %% [markdown]
# # COVID-19 Case Analysis

# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing and reading our dataset
dataset = pd.read_json("mohfw data.json")

# %%
dataset.head(10)
# Out:
#    sno                                state_name  active  positive    cured  \
# 0    2               Andaman and Nicobar Islands       2      7676     7545
# 1    1                            Andhra Pradesh    2265   2071244  2054553
# 2    3                         Arunachal Pradesh      38     55247    54929
# 3    4                                     Assam    2973    615382   606337
# 4    5                                     Bihar      40    726188   716485
# 5    6                                Chandigarh      30     65406    64556
# 6    7                              Chhattisgarh     295   1006542   992655
# 7    8  Dadra and Nagar Haveli and Daman and Diu       0     10682    10678
# 8   10                                     Delhi     309   1440666  1415262
# 9   11                                       Goa     235    178661   175048
#
#    death  new_active  new_positive  new_cured  new_death state_code
# ...

# %% [markdown]
# # Understanding and Playing with dataset

# %%
dataset.shape
# total rows and columns
# Out:
# (37, 11)

# %%
dataset.info()
# various types  of data present in the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           37 non-null     int64
#  1   state_name    37 non-null     object
#  2   active        37 non-null     int64
#  3   positive      37 non-null     int64
#  4   cured         37 non-null     int64
#  5   death         37 non-null     int64
#  6   new_active    37 non-null     int64
#  7   new_positive  37 non-null     int64
#  8   new_cured     37 non-null     int64
#  9   new_death     37 non-null     int64
#  10  state_code    37 non-null     object
# dtypes: int64(9), object(2)
# memory usage: 3.3+ KB

# %%
dataset.describe()
# viewing the statistical overview of the data like, count, mean,  standard deviation, percentage etc
# Out:
#                 sno         active      positive         cured          death  \
# count     37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean     319.054054    6402.324324  1.865887e+06  1.834300e+06   25184.378378
# std     1823.499245   21337.844899  5.696297e+06  5.598712e+06   78270.750718
# min        1.000000       0.000000  7.676000e+03  7.545000e+03       4.000000
# 25%       11.000000     119.000000  8.472100e+04  8.382700e+04     820.000000
# 50%       20.000000     280.000000  6.029800e+05  5.861170e+05    6072.000000
# 75%       29.000000    2265.000000  1.047003e+06  1.036501e+06   14426.000000
# max    11111.000000  118443.000000  3.451890e+07  3.393455e+07  465911.000000
#
#           new_active  new_positive     new_cured      new_death
# count      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean     6139.675676  1.866296e+06  1.834959e+06   25197.135135
# std     20358.810321  5.697570e+06  5.600783e+06   78308.693280
# ...

# %%
dataset.isnull().sum()
# no null values
# Out:
# sno             0
# state_name      0
# active          0
# positive        0
# cured           0
# death           0
# new_active      0
# new_positive    0
# new_cured       0
# new_death       0
# state_code      0
# dtype: int64

# %%
dataset.keys()
# all the columns names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
dataset.nunique()
# this function counts the distict observations over the requested axis.
# Out:
# sno             37
# state_name      37
# active          37
# positive        37
# cured           37
# death           37
# new_active      35
# new_positive    37
# new_cured       37
# new_death       37
# state_code      37
# dtype: int64

# %%
dataset.tail(10)
# shows last 10 columns of the dataset
# Out:
#       sno     state_name  active  positive     cured   death  new_active  \
# 27     29         Punjab     279    602980    586117   16584         262
# 28     30      Rajasthan     119    954606    945532    8955         131
# 29     31         Sikkim     123     32169     31643     403         116
# 30     32     Tamil Nadu    8722   2720271   2675174   36375        8616
# 31     34      Telangana    3575    674555    666999    3981        3538
# 32     33        Tripura      76     84721     83827     818          70
# 33     35    Uttarakhand     192    344106    336510    7404         175
# 34     36  Uttar Pradesh     102   1710332   1687321   22909         104
# 35     37    West Bengal    8020   1609845   1582442   19383        7945
# 36  11111                 118443  34518901  33934547  465911      113584
#
#     new_positive  new_cured  new_death state_code
# 27        603002     586154      16586         03
# 28        954628     945542       8955         08
# ...

# %%
dataset["active"].sum(axis= 0)
# total number of active cases in india till 23/10/2021
# Out:
# 236886

# %%
dataset["positive"].sum(axis= 0)
# total number of positive cases in india till 23/10/2021
# Out:
# 69037802

# %%
dataset["cured"].sum(axis= 0)
# total number of cured cases till 23/10/2021
# Out:
# 67869094

# %%
dataset["death"].sum(axis= 0)
# total number of deaths cases till 23/10/2021
# Out:
# 931822

# %%
dataset["new_active"].sum(axis= 0)
# total number of new_active cases till 23/10/2021
# Out:
# 227168

# %%
dataset["new_positive"].sum(axis= 0)
# total number of new_positive cases till 23/10/2021
# Out:
# 69052960

# %%
dataset["new_cured"].sum(axis= 0)
# total number of new_cured cases till 23/10/2021
# Out:
# 67893498

# %%
dataset["new_death"].sum(axis= 0)
# total number of new_deaths cases till 23/10/2021
# Out:
# 932294

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns

# %%
sns.pairplot(data= dataset)
# scatter plots plotting of all the data using pairplot

# %%
cases_ds = dataset.sum()
# storing total cases in cases_ds

# %%
cases_ds
# Out:
# sno                                                         11805
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                     236886
# positive                                                 69037802
# cured                                                    67869094
# death                                                      931822
# new_active                                                 227168
# new_positive                                             69052960
# new_cured                                                67893498
# new_death                                                  932294
# state_code      3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_ds.drop(["sno", "state_name", "state_code"], inplace= True)
# dropping the unnecessery columns

# %%
cases_ds
# Out:
# active            236886
# positive        69037802
# cured           67869094
# death             931822
# new_active        227168
# new_positive    69052960
# new_cured       67893498
# new_death         932294
# dtype: object

# %%
my_data = [236886, 69037802, 67869094, 931822]
my_labels = "Active", "Positive", "Cured", "Death"
my_explode = (1.5, 0, 0, 0)
my_colors = ["lightblue", "lightsteelblue", "lightpink", "black"]
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels = my_labels, autopct= "%1.1f%%", startangle= 15, shadow= True, colors= my_colors, explode= my_explode)
plt.axis("equal")
plt.show()
# pie chart visualization

# %%
cases_ds
# Out:
# active            236886
# positive        69037802
# cured           67869094
# death             931822
# new_active        227168
# new_positive    69052960
# new_cured       67893498
# new_death         932294
# dtype: object

# %%
my_data = [227168, 69052960, 67893498, 932294]
my_labels = "New Active", "New Positive", "New Cured", "New Death"
my_explode = (1.5, 0, 0, 0)
my_colors = ["lightblue", "lightsteelblue", "lightpink", "black"]
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels = my_labels, autopct= "%1.1f%%", startangle= 15, shadow= True, colors= my_colors, explode= my_explode)
plt.axis("equal")
plt.show()
# pie chart visualization

# %%
cases_ds
# Out:
# active            236886
# positive        69037802
# cured           67869094
# death             931822
# new_active        227168
# new_positive    69052960
# new_cured       67893498
# new_death         932294
# dtype: object

# %%
my_data = [236886, 69037802, 67869094, 931822, 227168, 69052960, 67893498, 932294]
my_labels = "Active", "Positive", "Cured", "Death", "New Active", "New Positive", "New Cured", "New Death"
my_explode = (1.5, 0, 0, 0, 0, 0, 0, 0)
my_colors = ["gray", "navajowhite","blanchedalmond", "gray", "lightblue", "papayawhip","moccasin", "lightpink"]
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels = my_labels, autopct= "%1.1f%%", startangle= 15, shadow= True, colors= my_colors, explode= my_explode)
plt.axis("equal")
plt.show()
# pie chart visualization

# %%
plt.rcParams["figure.figsize"]= (13, 8)
# fig size

# %%
dataset[["state_name", "active"]].groupby(["state_name"]).mean().sort_values(by= "active").plot.bar(color= "purple")
# Out:
# <AxesSubplot:xlabel='state_name'>

# %%
dataset[["state_name", "death"]].groupby(["state_name"]).mean().sort_values(by= "death").plot.bar(color= "purple")
# Out:
# <AxesSubplot:xlabel='state_name'>

# %%
dataset.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize= (13, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "active", color= "teal", data= dataset)
# this visualization shows the number of active cases are found in kerala and maharastra
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='active'>

# %%
plt.figure(figsize= (13, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "positive", color= "teal", data= dataset)
# this visualization shows the number of psotive cases are found in kerala and maharastra
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='positive'>

# %%
plt.figure(figsize= (13, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "cured", color= "teal", data= dataset)
# this visualization shows the number of cured cases are found in kerala and maharastra
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='cured'>

# %%
 plt.figure(figsize= (13, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "new_active", color= "teal", data= dataset)
# this visualization shows the number of new active cases are found in kerala and maharastra
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='new_active'>

# %%
plt.figure(figsize= (12, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "new_positive", color= "teal", data= dataset)
# this visualization shows the number of new positive cases and maharastra has the highest number of new positve cases
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='new_positive'>

# %%
plt.figure(figsize= (12, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "new_cured", color= "teal", data= dataset)
# this visualization shows the number of new cured cases and maharastra has the highest number of new cured cases and follwing by kerala
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='new_cured'>

# %%
plt.figure(figsize= (12, 8))
plt.xticks(rotation= 90)
sns.barplot(x= "state_name", y= "new_death", color= "teal", data= dataset)
# this visualization shows the number of new death cases and maharastra has the highest number of new death cases and follwing by kerala and karnataka
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='new_death'>

# %%
dataset.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
dataset.drop(["sno", "state_code"], axis= 1, inplace= True)

# %%
dataset.head(10)
# Out:
#                                  state_name  active  positive    cured  death  \
# 0               Andaman and Nicobar Islands       2      7676     7545    129
# 1                            Andhra Pradesh    2265   2071244  2054553  14426
# 2                         Arunachal Pradesh      38     55247    54929    280
# 3                                     Assam    2973    615382   606337   6072
# 4                                     Bihar      40    726188   716485   9663
# 5                                Chandigarh      30     65406    64556    820
# 6                              Chhattisgarh     295   1006542   992655  13592
# 7  Dadra and Nagar Haveli and Daman and Diu       0     10682    10678      4
# 8                                     Delhi     309   1440666  1415262  25095
# 9                                       Goa     235    178661   175048   3378
#
#    new_active  new_positive  new_cured  new_death
# 0           2          7676       7545        129
# ...

# %%
dataset = dataset.set_index("state_name")
# statename as index

# %%
dataset.head(10)
# Out:
#                                           active  positive    cured  death  \
# state_name
# Andaman and Nicobar Islands                    2      7676     7545    129
# Andhra Pradesh                              2265   2071244  2054553  14426
# Arunachal Pradesh                             38     55247    54929    280
# Assam                                       2973    615382   606337   6072
# Bihar                                         40    726188   716485   9663
# Chandigarh                                    30     65406    64556    820
# Chhattisgarh                                 295   1006542   992655  13592
# Dadra and Nagar Haveli and Daman and Diu       0     10682    10678      4
# Delhi                                        309   1440666  1415262  25095
# Goa                                          235    178661   175048   3378
#
#                                           new_active  new_positive  new_cured  \
# state_name
# ...

# %%
dataset.plot.barh(stacked = True, figsize = (13, 8))
# stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
dataset1 = dataset[["cured", "death"]]
dataset1.plot.barh(color= {"cured": "aquamarine", "death": "red"}, figsize= (13, 8))
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
dataset2 = dataset[["positive", "death"]]
dataset2.plot.barh(color= {"positive": "aquamarine", "death": "red"}, figsize= (13, 8))
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
dataset3 = dataset[["death", "cured"]]
dataset3.plot.barh(color= {"death": "red", "cured": "aquamarine"}, figsize= (13, 8))
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
dataset3 = dataset[["active", "death"]]
dataset3.plot.barh(color= {"active": "black", "death": "orange"}, figsize= (13, 8))
# Out:
# <AxesSubplot:ylabel='state_name'>

# %% [markdown]
# ##### So its clear that Covid-19 Maharastra has the maximum number of Positive, Death, New positive cases. As the affected number is most thats why the cured cases are also the most over there in Maharastra. Kerala Has gone through a big disaster as well. States like Dadra and Nagar Haveli and Daman and Diu, Lakshadweep, Andaman and Nicobar island, Ladakh are almost covid free. Covid-19 didn't get any advantages there.
